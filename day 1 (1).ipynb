# %% [markdown]
# # **Print**

# %%
print("hello programmer! abdur rahim")
# Out:
# hello programmer! abdur rahim

# %%
print("21 day challage of python")
# Out:
# 21 day challage of python

# %%
print(100)
# Out:
# 100

# %%
print("my age ", 22, "year")
# Out:
# my age  22 year

# %%
name = "Rahim"
age = 22
print("my name", name, " my age", age, "year")
# Out:
# my name Rahim  my age 22 year

# %%
name = "Rahim"
age = 22
print(f"my name {name}, my age {age} বছর")

# %% [markdown]
# # **sum, substraction, multiple, division, remainder**

# %%
#sum
number1 = 20
number2 =50
sum= number1+number2
print(sum)
# Out:
# 70

# %%
#subtraction
number1 = 20
number2 =50
subtraction= number1-number2
print(subtraction)
# Out:
# -30

# %%
#multiple

number1 = 20
number2 =50
multiple= number1*number2
print(multiple)
# Out:
# 1000

# %%
#division

number1 = 1080
number2 =50
division= number1/number2
print(division)
# Out:
# 21.6

# %%
#remainder
number1 = 1020
number2 =50
x = number1%number2
print(x)
# Out:
# 20

# %%
number1 = 1020
number2 =50
x = number1//number2
print(x)
# Out:
# 20

# %%
#square
number1 = 2
number2 =2
x = number1**number2
print(x)
# Out:
# 4

# %% [markdown]
# ## **temperature**  **related**

# %%
temperature =36
if(temperature>20):
  print("hot")
# Out:
# hot

# %%
temperature = 25
if(temperature>=25):
  print("normal")
# Out:
# normal

# %%
temperature =36
if(temperature>225):
  print("hot")
else:
  print("cold")
# Out:
# cold

# %%
temperature =36
if(temperature>25):
  print("hot")
elif(temperature>=25):
    print("normal")
else:
  print("cold")
# Out:
# hot

# %%
#charecter
my_list=['apple, banana, orrange']
print(my_list)
# Out:
# ['apple, banana, orrange']

# %%
my_list=['apple, banana, orrange']
for i in my_list :
  print(i)
# Out:
# apple, banana, orrange
